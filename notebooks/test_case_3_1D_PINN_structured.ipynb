# %%
#from typing import List, Tuple
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import time

def domain(n,pars):

    t = np.random.uniform(low=0,high=pars['tf'],size=(n,1))
    x = np.random.uniform(low=pars['xi'],high=pars['xf'],size=(n,1))

    X = np.hstack((t,x))

    return X

class MLP(nn.Module):
    
    # Define the MLP

    def __init__(
        self, pars, device
    ) -> None:

        super().__init__()

        # Add number of MLP input and outputs to the layers list
        layers = [2,*pars['layers'],2]
        
        # Built the MLP
        modules = []
        for _in, _out in list(zip(layers, layers[1:])):
            modules.append(nn.Linear(_in, _out))
            modules.append(ResidualBlock(_out))
        
        # Remove last block
        modules.pop()

        self.model = nn.Sequential(*modules)

    def forward(self, X: torch.Tensor) -> torch.Tensor:

        # Forward pass
        Y_n = self.model(X)
        Y_p = self.particular_solution(X)
        D = self.boundary_distance(X)

        return D * Y_n + (1-D) * Y_p

    def particular_solution(self,X):
        x = X[:,1].reshape(-1, 1)

        u = 2*0.05*torch.pi*torch.sin(torch.pi*(1+x)/2)/(2+torch.cos(torch.pi*(1+x)/2))

        return u

    def boundary_distance(self,X):

        alpha = 26.4 # Reaches 0.99 at t = 0.1
        #alpha = 10.56 # Reaches 0.99 at t = 0.25

        t = X[:,0].reshape(-1, 1)
        x = X[:,1].reshape(-1, 1)

        dt = torch.tanh(t*alpha)
        dx = 4*(0.5*x+0.5)*(1-(0.5*x+0.5))

        return torch.hstack((dt*dx,dt*dx))

class ResidualBlock(nn.Module):

    # Define a block with two layers and a residual connection
    def __init__(self,_size:int):
        super().__init__()
        self.Layer1 = nn.Tanh()
        self.Linear = nn.Linear(_size, _size)
        self.Layer2 = nn.Tanh()

    def forward(self,x):
        return x + self.Layer2(self.Linear(self.Layer1(x)))

class PINN:
    def __init__(self, nf, pars: dict, device: torch.device = 'cuda') -> None:

        # Parameters
        self.pars = pars
        self.device = device
        self.nf = nf
        self.nu = pars['nu']

        self.ls_f1 = torch.tensor(0).to(self.device)
        self.ls_f2 = torch.tensor(0).to(self.device)
        self.ls_f = torch.tensor(0).to(self.device)
        self.ls_s = torch.tensor(0).to(self.device)

        # Sample points
        self.sample_points()
        self.zeros = torch.zeros(self.X_f.shape).to(self.device)

        # Initialize Network
        self.net = MLP(pars,device)
        self.net = self.net.to(device)

        if pars['loss_type'] == 'l1':
            self.loss = nn.L1Loss().to(device)
        elif pars['loss_type'] == 'mse':
            self.loss = nn.MSELoss().to(device)

        self.min_ls_tol = 0.01
        self.min_ls_wait = 10000
        self.min_ls_window = 1000

        self.start_time = time.time()

        self.ls = 0
        self.iter = 0

        self.ls_hist = np.zeros((pars['epochs'],2))

        # Optimizer parameters
        if pars['opt_method'] == 'adam':
            self.optimizer = torch.optim.Adam(self.net.parameters(),lr=pars['opt_lr'])
        elif pars['opt_method'] == 'lbfgs':
            self.optimizer = torch.optim.LBFGS(self.net.parameters(),lr=pars['opt_lr'])
        elif pars['opt_method'] == 'sgd':
            self.optimizer = torch.optim.SGD(self.net.parameters(),lr=pars['opt_lr'])
        else:
            raise Exception("Unknown optimization method")

    def sample_points(self):
        X_f = domain(self.nf,self.pars)
        self.X_f = torch.tensor(X_f,dtype=torch.float,requires_grad=True).to(self.device)

    def eq_loss(self, X: torch.Tensor):

        # Forward pass
        t = X[:,0].reshape(-1, 1)
        x = X[:,1].reshape(-1, 1)
        Y = self.net(torch.hstack((t,x)))
        
        u = Y[:,0].reshape(-1, 1)

        # Get derivatives
        u_t = torch.autograd.grad(u, t, grad_outputs=torch.ones_like(u),
                                  retain_graph=True, create_graph=True)[0]
        u_x = torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
                                  retain_graph=True, create_graph=True)[0]
        u_xx = torch.autograd.grad(u_x, x, grad_outputs=torch.ones_like(u),
                                  retain_graph=True, create_graph=True)[0]

        # Compute residuals
        R1 = u_t + 2*u*u_x - 0.2*u_xx

        self.ls_f = self.loss(R1,torch.zeros_like(R1))

        return self.ls_f

    def closure(self) -> torch.nn:
        if self.nf > 0:
            self.ls_f = self.eq_loss(self.X_f)
            
        if self.nf > 0:
            self.ls = self.ls_f

        self.optimizer.zero_grad()
        self.ls.backward()

        return self.ls

    def stopping(self):
        # Stop the training if the median loss of the last min_ls_window steps is not improved in min_ls_wait by a factor of min_ls_tol
        if self.iter > self.min_ls_wait + self.min_ls_window:

            old_list = sorted(self.ls_hist[self.iter-self.min_ls_wait-self.min_ls_window+1:self.iter-self.min_ls_wait,0])
            new_list = sorted(self.ls_hist[self.iter-self.min_ls_window+1:self.iter,0])
            median_ind = self.min_ls_window//2

            if new_list[median_ind] > old_list[median_ind] * (1-self.min_ls_tol):
                return True

        return False

    def train(self):
        self.net.train()

        for i in range(1,self.pars['epochs']):
            self.iter += 1

            if self.pars['shuffle'] and i%self.pars['shuffle']==0:
                self.sample_points()

            try:
                self.optimizer.step(self.closure)
            except KeyboardInterrupt:
                print("Stopped by user")
                self.save(0)
                try:
                    input('Press Enter to resume or Ctrl+C again to stop')
                except KeyboardInterrupt:
                    break
                
            if i%50 == 0:
                print(f'Epoch: {self.iter}, Loss: {self.ls:.3e}, Loss_F: {self.ls_f:.3e}')
                
            self.ls_hist[i,:] = torch.hstack((self.ls,self.ls_f)).cpu().detach().numpy()

# %%
pars = {}
pars['xi'] = -1
pars['xf'] = 1
pars['yi'] = -1
pars['yf'] = 1
pars['tf'] = 1
pars['nu'] = 0.01/np.pi
pars['layers'] = [20, 20, 20, 20]
pars['loss_type'] = 'l1'
pars['opt_method'] = 'adam'
pars['epochs'] = 5000
pars['opt_lr'] = 0.01
pars['shuffle'] = 0
device="cuda" if torch.cuda.is_available() else "cpu"

model = PINN(10000, pars, device=device)
model.train()
# Out:
# Epoch: 50, Loss: 3.707e-02, Loss_F: 3.707e-02
# Epoch: 100, Loss: 3.120e-02, Loss_F: 3.120e-02
# Epoch: 150, Loss: 2.588e-02, Loss_F: 2.588e-02
# Epoch: 200, Loss: 1.002e-02, Loss_F: 1.002e-02
# Epoch: 250, Loss: 1.079e-02, Loss_F: 1.079e-02
# Epoch: 300, Loss: 5.144e-03, Loss_F: 5.144e-03
# Epoch: 350, Loss: 1.085e-02, Loss_F: 1.085e-02
# Epoch: 400, Loss: 2.186e-02, Loss_F: 2.186e-02
# Epoch: 450, Loss: 1.415e-02, Loss_F: 1.415e-02
# Epoch: 500, Loss: 9.870e-03, Loss_F: 9.870e-03
# Epoch: 550, Loss: 1.087e-02, Loss_F: 1.087e-02
# Epoch: 600, Loss: 7.713e-03, Loss_F: 7.713e-03
# Epoch: 650, Loss: 8.594e-03, Loss_F: 8.594e-03
# Epoch: 700, Loss: 5.861e-03, Loss_F: 5.861e-03
# Epoch: 750, Loss: 1.727e-02, Loss_F: 1.727e-02
# Epoch: 800, Loss: 6.220e-03, Loss_F: 6.220e-03
# Epoch: 850, Loss: 7.343e-03, Loss_F: 7.343e-03
# Epoch: 900, Loss: 1.097e-02, Loss_F: 1.097e-02
# Epoch: 950, Loss: 1.255e-02, Loss_F: 1.255e-02
# Epoch: 1000, Loss: 4.096e-03, Loss_F: 4.096e-03
# Epoch: 1050, Loss: 6.252e-03, Loss_F: 6.252e-03
# Epoch: 1100, Loss: 8.676e-03, Loss_F: 8.676e-03
# Epoch: 1150, Loss: 6.761e-03, Loss_F: 6.761e-03
# Epoch: 1200, Loss: 1.071e-02, Loss_F: 1.071e-02
# Epoch: 1250, Loss: 6.751e-03, Loss_F: 6.751e-03
# Epoch: 1300, Loss: 8.547e-03, Loss_F: 8.547e-03
# Epoch: 1350, Loss: 8.474e-03, Loss_F: 8.474e-03
# Epoch: 1400, Loss: 3.414e-03, Loss_F: 3.414e-03
# Epoch: 1450, Loss: 6.173e-03, Loss_F: 6.173e-03
# Epoch: 1500, Loss: 7.569e-03, Loss_F: 7.569e-03
# Epoch: 1550, Loss: 6.262e-03, Loss_F: 6.262e-03
# Epoch: 1600, Loss: 9.164e-03, Loss_F: 9.164e-03
# Epoch: 1650, Loss: 4.562e-03, Loss_F: 4.562e-03
# Epoch: 1700, Loss: 5.189e-03, Loss_F: 5.189e-03
# Epoch: 1750, Loss: 4.151e-03, Loss_F: 4.151e-03
# Epoch: 1800, Loss: 7.972e-03, Loss_F: 7.972e-03
# Epoch: 1850, Loss: 4.967e-03, Loss_F: 4.967e-03
# Epoch: 1900, Loss: 5.375e-03, Loss_F: 5.375e-03
# Epoch: 1950, Loss: 6.441e-03, Loss_F: 6.441e-03
# Epoch: 2000, Loss: 7.041e-03, Loss_F: 7.041e-03
# Epoch: 2050, Loss: 5.254e-03, Loss_F: 5.254e-03
# Epoch: 2100, Loss: 7.485e-03, Loss_F: 7.485e-03
# Epoch: 2150, Loss: 6.040e-03, Loss_F: 6.040e-03
# Epoch: 2200, Loss: 4.230e-03, Loss_F: 4.230e-03
# Epoch: 2250, Loss: 5.161e-03, Loss_F: 5.161e-03
# Epoch: 2300, Loss: 5.173e-03, Loss_F: 5.173e-03
# Epoch: 2350, Loss: 4.581e-03, Loss_F: 4.581e-03
# Epoch: 2400, Loss: 2.680e-03, Loss_F: 2.680e-03
# Epoch: 2450, Loss: 7.307e-03, Loss_F: 7.307e-03
# Epoch: 2500, Loss: 4.825e-03, Loss_F: 4.825e-03
# Epoch: 2550, Loss: 3.624e-03, Loss_F: 3.624e-03
# Epoch: 2600, Loss: 6.039e-03, Loss_F: 6.039e-03
# Epoch: 2650, Loss: 3.153e-03, Loss_F: 3.153e-03
# Epoch: 2700, Loss: 5.458e-03, Loss_F: 5.458e-03
# Epoch: 2750, Loss: 4.859e-03, Loss_F: 4.859e-03
# Epoch: 2800, Loss: 8.635e-03, Loss_F: 8.635e-03
# Epoch: 2850, Loss: 5.050e-03, Loss_F: 5.050e-03
# Epoch: 2900, Loss: 4.005e-03, Loss_F: 4.005e-03
# Epoch: 2950, Loss: 6.593e-03, Loss_F: 6.593e-03
# Epoch: 3000, Loss: 4.903e-03, Loss_F: 4.903e-03
# Epoch: 3050, Loss: 3.803e-03, Loss_F: 3.803e-03
# Epoch: 3100, Loss: 6.372e-03, Loss_F: 6.372e-03
# Epoch: 3150, Loss: 2.239e-03, Loss_F: 2.239e-03
# Epoch: 3200, Loss: 7.222e-03, Loss_F: 7.222e-03
# Epoch: 3250, Loss: 6.103e-03, Loss_F: 6.103e-03
# Epoch: 3300, Loss: 2.706e-03, Loss_F: 2.706e-03
# Epoch: 3350, Loss: 4.266e-03, Loss_F: 4.266e-03
# Epoch: 3400, Loss: 2.867e-03, Loss_F: 2.867e-03
# Epoch: 3450, Loss: 5.100e-03, Loss_F: 5.100e-03
# Epoch: 3500, Loss: 3.687e-03, Loss_F: 3.687e-03
# Epoch: 3550, Loss: 4.162e-03, Loss_F: 4.162e-03
# Epoch: 3600, Loss: 4.542e-03, Loss_F: 4.542e-03
# Epoch: 3650, Loss: 3.972e-03, Loss_F: 3.972e-03
# Epoch: 3700, Loss: 1.788e-03, Loss_F: 1.788e-03
# Epoch: 3750, Loss: 2.823e-03, Loss_F: 2.823e-03
# Epoch: 3800, Loss: 6.166e-03, Loss_F: 6.166e-03
# Epoch: 3850, Loss: 3.017e-03, Loss_F: 3.017e-03
# Epoch: 3900, Loss: 3.635e-03, Loss_F: 3.635e-03
# Epoch: 3950, Loss: 6.243e-03, Loss_F: 6.243e-03
# Epoch: 4000, Loss: 2.865e-03, Loss_F: 2.865e-03
# Epoch: 4050, Loss: 3.514e-03, Loss_F: 3.514e-03
# Epoch: 4100, Loss: 5.262e-03, Loss_F: 5.262e-03
# Epoch: 4150, Loss: 4.205e-03, Loss_F: 4.205e-03
# Epoch: 4200, Loss: 5.023e-03, Loss_F: 5.023e-03
# Epoch: 4250, Loss: 5.202e-03, Loss_F: 5.202e-03
# Epoch: 4300, Loss: 5.433e-03, Loss_F: 5.433e-03
# Epoch: 4350, Loss: 3.086e-03, Loss_F: 3.086e-03
# Epoch: 4400, Loss: 5.366e-03, Loss_F: 5.366e-03
# Epoch: 4450, Loss: 4.819e-03, Loss_F: 4.819e-03
# Epoch: 4500, Loss: 3.514e-03, Loss_F: 3.514e-03
# Epoch: 4550, Loss: 4.300e-03, Loss_F: 4.300e-03
# Epoch: 4600, Loss: 4.472e-03, Loss_F: 4.472e-03
# Epoch: 4650, Loss: 5.362e-03, Loss_F: 5.362e-03
# Epoch: 4700, Loss: 3.713e-03, Loss_F: 3.713e-03
# Epoch: 4750, Loss: 5.063e-03, Loss_F: 5.063e-03
# Epoch: 4800, Loss: 4.351e-03, Loss_F: 4.351e-03
# Epoch: 4850, Loss: 4.204e-03, Loss_F: 4.204e-03
# Epoch: 4900, Loss: 3.623e-03, Loss_F: 3.623e-03
# Epoch: 4950, Loss: 5.218e-03, Loss_F: 5.218e-03

# %%
mu = 0.05
dim = 1 
m=2
    
def exact_example(t, x, T):
    xi = (1+sum(x))/2
    return 2*np.pi*mu*np.exp(-np.pi**2*mu*dim*(T-t))*np.sin(np.pi*xi)/(m+np.exp(-np.pi**2*mu*dim*(T-t))*np.cos(np.pi*xi))

# %%
dim = 1
grid = np.expand_dims(np.linspace(-1, 1, 100), axis=0)
tmax = 1
time_list = [0, 0.1]

for time in time_list:
    t = time * np.ones((1, 100))
    x = grid
    
    grid_d_dim_with_t = np.concatenate([t.T, x.T], axis=1).astype('float32')
    
    pinn_sol = model.net(torch.from_numpy(grid_d_dim_with_t).to(device))
    
    initial = model.net.particular_solution(torch.from_numpy(grid_d_dim_with_t))
    
    plt.plot(grid[0], pinn_sol.cpu().detach().numpy()[:,0], label=f"t={time:.2f}")
plt.xlabel('x')
plt.ylabel('u(t,x)')
plt.plot(grid[0], initial[:, 0], 'r--', label='Initial Condition')
plt.plot(grid[0], exact_example(0, grid, 0.1), 'g--', label='True Solution')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show()

# %%
torch.save(model.net.state_dict(), '../logs/models/pinn_test_case_3_dim_1_model.pth')
